# %%
import requests
import json
import time
import pandas as pd

API_KEY = 'fnhdgteef55nyjm4cxpj3828'

# teams_url = f"https://api.sportradar.us/nfl/official/trial/v7/en/seasons/2021/REG/01/depth_charts.json?api_key={API_KEY}"
# team_data = requests.get(teams_url)
# team_info = team_data.json()['teams']
# team_ids = list(map(lambda x: {'id': x['id'], 'name': x['name']}, team_info))

# with open('team_ids.json', 'w') as f:
#     json.dump(team_ids, f)

with open('team_ids.json') as f:
    teams = json.load(f)
    
all_team_penalties = []
# for year in range(2010, 2022):
#     for team in teams:
#         try:
#             url = f"https://api.sportradar.us/nfl/official/trial/v7/en/seasons/{year}/REG/teams/{team['id']}/statistics.json?api_key={API_KEY}"
#             data = requests.get(url)
#             penalties = data.json()['record']['penalties']
#             penalties['name'] = team['name']
#             penalties['year'] = year
#             all_team_penalties.append(penalties)
#             time.sleep(1)
#         except Exception as error:
#             print(url)
#             print(data)
#             print(str(error))
#             time.sleep(1)
    
# df = pd.DataFrame(all_team_penalties)

# df.to_csv('penalties.csv', index=False)

# %%
import numpy as np
from plotnine import *
pd.set_option('display.max_rows', 500)

TEAMS = ['Raiders', 'Cowboys', '49ers', 'Vikings', 'Browns', 'Chargers', 'Cardinals',
 'Bills', 'Texans', 'Titans', 'Chiefs', 'Bears', 'Buccaneers', 'Panthers', 'Jets',
 'Jaguars', 'Patriots', 'Ravens', 'Eagles', 'Steelers', 'Dolphins', 'Lions',
 'Saints', 'Seahawks', 'Falcons', 'Football Team', 'Broncos', 'Colts', 'Packers',
 'Giants', 'Rams', 'Bengals']
YEARS = range(2010, 2022)

df = pd.read_csv('penalties_new.csv')

mean = df.groupby(['year', 'name']).mean().sort_values(by=['year', 'yards'], ascending=False)

mean = mean.reset_index()

total_rankings = []

for year in YEARS:
    year_rank = {'year': year}
    for team in TEAMS:
        val = mean[(mean['year'] == year) & (mean['name'] == team)]
        if year == 2021:
            print(val)
        rank = (list(val.index)[0] + 1) % 32
        year_rank[team] = rank or 32
    total_rankings.append(year_rank)
    
df = pd.DataFrame(total_rankings)
df.to_csv('cumulative_rankings_yards.csv', index=False)
# Out:
#      year           name  penalties   yards
# 0    2021        Raiders      124.0  1104.0
# 1    2021        Cowboys      127.0  1103.0
# 2    2021          49ers      102.0  1066.0
# 3    2021        Vikings      111.0  1043.0
# 4    2021         Browns      112.0  1035.0
# 5    2021       Chargers      116.0  1033.0
# 6    2021      Cardinals      114.0   990.0
# 7    2021          Bills      113.0   980.0
# 8    2021         Texans      114.0   978.0
# 9    2021         Titans      103.0   973.0
# 10   2021         Chiefs      111.0   925.0
# 11   2021          Bears      106.0   914.0
# 12   2021     Buccaneers       97.0   874.0
# 13   2021       Panthers      107.0   864.0
# 14   2021           Jets      103.0   860.0
# 15   2021        Jaguars      104.0   856.0
# 16   2021       Patriots       95.0   854.0
# 17   2021         Ravens      102.0   852.0
# 18   2021         Eagles      107.0   842.0
# 19   2021       Steelers      106.0   831.0
# 20   2021       Dolphins      105.0   825.0
# 21   2021          Lions      105.0   824.0
# 22   2021         Saints       98.0   811.0
# 23   2021       Seahawks       97.0   803.0
# 336  2011         Saints       99.0   851.0
# 337  2011           Jets      102.0   849.0
# 338  2011         Browns       95.0   847.0
# 339  2011        Broncos      101.0   842.0
# 340  2011        Cowboys      114.0   816.0
# 341  2011       Patriots       87.0   815.0
# 342  2011          Bears      104.0   800.0
# 343  2011         Giants       94.0   795.0
# 344  2011       Dolphins       85.0   779.0
# 345  2011        Falcons       93.0   769.0
# 346  2011       Chargers       91.0   753.0
# 347  2011          Bills       86.0   743.0
# 348  2011         Ravens       92.0   742.0
# 349  2011        Jaguars       77.0   680.0
# 350  2011        Packers       76.0   591.0
# 351  2011          Colts       76.0   549.0
# 352  2010        Raiders      148.0  1276.0
# 353  2010         Eagles      129.0  1101.0
# 354  2010         Titans      128.0  1040.0
# 355  2010          Lions      136.0  1018.0
# 356  2010        Broncos       98.0   944.0
# 357  2010           Jets      103.0   934.0
# 358  2010          49ers      112.0   933.0
# 359  2010       Panthers      106.0   918.0
# 360  2010       Steelers      100.0   903.0
# 361  2010       Seahawks      101.0   890.0
# 362  2010         Saints       90.0   884.0
# 363  2010           Rams      102.0   877.0
# 364  2010      Cardinals      108.0   870.0
# 365  2010        Cowboys      109.0   863.0
# 366  2010     Buccaneers      100.0   837.0
# 367  2010         Giants       92.0   777.0
# 368  2010         Chiefs       90.0   771.0
# 369  2010        Vikings      100.0   769.0
# 370  2010          Bears       91.0   768.0
# 371  2010       Patriots       83.0   766.0
# 372  2010        Bengals       90.0   720.0
# 373  2010          Colts       79.0   709.0
# 374  2010         Texans       90.0   690.0
# 375  2010       Chargers       84.0   677.0
# 376  2010         Browns       78.0   675.0
# 377  2010        Jaguars       83.0   675.0
# 378  2010         Ravens       90.0   673.0
# 379  2010  Football Team       90.0   647.0
# 380  2010          Bills       82.0   633.0
# 381  2010        Packers       78.0   617.0
# 382  2010        Falcons       58.0   598.0
# 383  2010       Dolphins       72.0   595.0
#    year     name  penalties   yards
# 0  2021  Raiders      124.0  1104.0
#    year     name  penalties   yards
# 1  2021  Cowboys      127.0  1103.0
#    year   name  penalties   yards
# 2  2021  49ers      102.0  1066.0
#    year     name  penalties   yards
# 3  2021  Vikings      111.0  1043.0
#    year    name  penalties   yards
# 4  2021  Browns      112.0  1035.0
#    year      name  penalties   yards
# 5  2021  Chargers      116.0  1033.0
#    year       name  penalties  yards
# 6  2021  Cardinals      114.0  990.0
#    year   name  penalties  yards
# 7  2021  Bills      113.0  980.0
#    year    name  penalties  yards
# 8  2021  Texans      114.0  978.0
#    year    name  penalties  yards
# 9  2021  Titans      103.0  973.0
#     year    name  penalties  yards
# 10  2021  Chiefs      111.0  925.0
#     year   name  penalties  yards
# 11  2021  Bears      106.0  914.0
#     year        name  penalties  yards
# 12  2021  Buccaneers       97.0  874.0
#     year      name  penalties  yards
# 13  2021  Panthers      107.0  864.0
#     year  name  penalties  yards
# 14  2021  Jets      103.0  860.0
#     year     name  penalties  yards
# 15  2021  Jaguars      104.0  856.0
#     year      name  penalties  yards
# 16  2021  Patriots       95.0  854.0
#     year    name  penalties  yards
# 17  2021  Ravens      102.0  852.0
#     year    name  penalties  yards
# 18  2021  Eagles      107.0  842.0
#     year      name  penalties  yards
# 19  2021  Steelers      106.0  831.0
#     year      name  penalties  yards
# 20  2021  Dolphins      105.0  825.0
#     year   name  penalties  yards
# 21  2021  Lions      105.0  824.0
#     year    name  penalties  yards
# 22  2021  Saints       98.0  811.0
#     year      name  penalties  yards
# 23  2021  Seahawks       97.0  803.0
#     year     name  penalties  yards
# 24  2021  Falcons       92.0  753.0
#     year           name  penalties  yards
# 25  2021  Football Team       82.0  743.0
#     year     name  penalties  yards
# 26  2021  Broncos       83.0  711.0
#     year   name  penalties  yards
# 27  2021  Colts       76.0  688.0
#     year     name  penalties  yards
# 28  2021  Packers       69.0  678.0
#     year    name  penalties  yards
# 29  2021  Giants       88.0  674.0
#     year  name  penalties  yards
# 30  2021  Rams       76.0  637.0
#     year     name  penalties  yards
# 31  2021  Bengals       72.0  620.0

# %%
import pandas as pd

df = pd.read_csv('penalties_new.csv')

for idx, num in enumerate(df.groupby('year').mean().yards):
    new_row = {'year': YEARS[idx], 'name': 'Average', 'yards': round(num, 0)}
    df = df.append(new_row, ignore_index=True)
    

df.drop(columns=['penalties'], inplace=True)
df = df.set_index(['name', 'year'])['yards'].unstack()
df.to_csv('penalties_yards_with_average.csv')
# Out:
# year             2010    2011    2012    2013    2014    2015    2016    2017  \
# name
# 49ers           933.0  1014.0   960.0   845.0   937.0   823.0   831.0   988.0
# Average         814.0   867.0   851.0   845.0   888.0   940.0   928.0   924.0
# Bears           768.0   800.0   811.0   708.0   997.0   909.0   967.0   943.0
# Bengals         720.0   874.0   857.0  1000.0   812.0   917.0   726.0  1027.0
# Bills           633.0   743.0   871.0   952.0  1031.0  1249.0   960.0   872.0
# Broncos         944.0   842.0   805.0  1000.0  1045.0  1063.0   985.0   885.0
# Browns          675.0   847.0  1005.0   920.0   932.0  1083.0   736.0   924.0
# Buccaneers      837.0  1007.0   819.0  1136.0   939.0  1195.0   926.0   795.0
# Cardinals       870.0  1004.0   857.0   744.0   707.0   758.0   889.0   880.0
# Chargers        677.0   753.0   796.0   765.0   967.0   942.0   780.0   927.0
# Chiefs          771.0   916.0   733.0   774.0   681.0   878.0   848.0  1044.0
# Colts           709.0   549.0   801.0   576.0   848.0   931.0   883.0   779.0
# Cowboys         863.0   816.0   853.0   867.0   839.0   879.0   879.0   939.0
# Dolphins        595.0   779.0   724.0   598.0   635.0  1090.0  1141.0  1154.0
# Eagles         1101.0   853.0   813.0   846.0   995.0   819.0   945.0   962.0
# Falcons         598.0   769.0   415.0   788.0   840.0   969.0   847.0   918.0
# Football Team   647.0   897.0   985.0   802.0  1130.0   827.0   909.0   732.0
# Giants          777.0   795.0   578.0   786.0   896.0   779.0   857.0   895.0
# Jaguars         675.0   680.0   955.0   797.0   573.0   880.0  1178.0   936.0
# Jets            934.0   849.0   708.0   837.0   932.0   787.0   837.0  1035.0
# Lions          1018.0  1075.0   944.0   925.0   989.0   930.0   861.0   968.0
# Packers         617.0   591.0   923.0   801.0   775.0   906.0   827.0   789.0
# Panthers        918.0  1013.0   835.0   671.0   756.0   887.0   850.0   682.0
# Patriots        766.0   815.0   840.0   625.0  1080.0   859.0   819.0   835.0
# Raiders        1276.0  1358.0   939.0   912.0   939.0  1102.0  1251.0  1009.0
# Rams            877.0   899.0   978.0  1009.0  1139.0  1007.0  1091.0   922.0
# Ravens          673.0   742.0  1127.0   942.0   870.0  1153.0  1111.0   749.0
# Saints          884.0   851.0   911.0   817.0   670.0  1112.0   969.0   962.0
# Seahawks        890.0  1047.0   890.0  1183.0  1009.0  1007.0   970.0  1342.0
# Steelers        903.0   854.0   938.0   677.0   834.0   868.0  1068.0   896.0
# Texans          690.0   852.0   873.0  1138.0   834.0   910.0   868.0  1050.0
# Titans         1040.0   960.0   847.0   900.0   961.0   779.0  1012.0   785.0
# Vikings         769.0   908.0   830.0   695.0   836.0   797.0   882.0   949.0
#
# year             2018    2019    2020    2021
# name
# 49ers           982.0   939.0   731.0  1066.0
# Average         919.0   916.0   779.0   867.0
# Bears           796.0   838.0   777.0   914.0
# Bengals         957.0   761.0   675.0   620.0
# Bills           992.0   927.0   941.0   980.0
# Broncos         985.0   912.0   670.0   711.0
# Browns          894.0  1106.0   870.0  1035.0
# Buccaneers      975.0  1111.0   715.0   874.0
# Cardinals       786.0   956.0   868.0   990.0
# Chargers        967.0   872.0   710.0  1033.0
# Chiefs         1152.0  1029.0   919.0   925.0
# Colts           953.0   670.0   899.0   688.0
# Cowboys         885.0  1008.0   849.0  1103.0
# Dolphins        978.0   769.0   635.0   825.0
# Eagles          852.0   836.0   853.0   842.0
# Falcons         899.0   956.0   736.0   753.0
# Football Team  1008.0   835.0   697.0   743.0
# Giants          951.0   784.0   634.0   674.0
# Jaguars        1112.0  1165.0  1071.0   856.0
# Jets            948.0  1105.0   952.0   860.0
# Lions           852.0   937.0   860.0   824.0
# Packers         937.0   774.0   684.0   678.0
# Panthers        818.0   754.0   752.0   864.0
# Patriots        744.0   828.0   534.0   854.0
# Raiders         965.0  1138.0   856.0  1104.0
# Rams            878.0   899.0   655.0   637.0
# Ravens          940.0   867.0   961.0   852.0
# Saints          939.0  1036.0  1005.0   811.0
# Seahawks        959.0   882.0   662.0   803.0
# Steelers       1026.0   893.0   691.0   831.0
# Texans          787.0   892.0   619.0   978.0
# Titans          727.0   932.0   783.0   973.0
# Vikings         779.0   895.0   650.0  1043.0

# %%
import pandas as pd

df = pd.read_csv('penalties_new.csv')

for idx, num in enumerate(df.groupby('year').mean().penalties):
    new_row = {'year': YEARS[idx], 'name': 'Average', 'penalties': round(num, 0)}
    df = df.append(new_row, ignore_index=True)
    

df.drop(columns=['yards'], inplace=True)
df = df.set_index(['year', 'name'])['penalties'].unstack()
df.to_csv('penalties_total_with_average.csv')

# %%
import pandas as pd

df = pd.read_csv('cumulative_rankings.csv')
top_5 = []
for row_num in range(32):
    top_5_tally = 0
    row = df.iloc[row_num]
    for year in YEARS:
        yearly_position = row[str(year)]
        if yearly_position <= 5:
            top_5_tally += 1
    top_5.append({'team': row['team'], 'num_seasons': top_5_tally})
    
df = pd.DataFrame(top_5)
df.to_csv('num_seasons_yards.csv', index=False)
